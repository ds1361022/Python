# %% [markdown]
# # Debugging in Spyder
# In this assignment you will use Spyder to navigate in and modify programs as they run.

# %% [markdown]
# *0. Create a **new project in spyder**. Create a new directory for it. Add a file named **SpyderBug.py**. Put the code below as-is in SpyderBug.py. Use "File⇨Save As" to **store the file in your project's directory.** Run your program and **confirm that it runs properly**. If it doesn't, make sure you copied all of the below into the scriptfile.*

# %%
MPCastPhrases = {
    "Cleese": "It's not pining, it's passed on! This parrot is no more!\
    It has ceased to be! It's expired and gone to meet its maker! This\
    is a late parrot! It's a stiff! Bereft of life, it rests in peace!\
    If you hadn't nailed it to the perch, it would be pushing up the\
    daisies! It's rung down the curtain and joined the choir invisible.\
    This is an ex-parrot!",
    "Palin": "Bally Jerry pranged his kite right in the how's-your-father;\
    hairy blighter, dicky-birded, feathered back on his sammy, took a waspy,\
    flipped over on his Betty Harpers and caught his can in the Bertie.",
    "Jones": "Spam! Spam! Spam! Spam! Spam! Spam!",
    "Idle": "Nobody expects the Spanish Inquisition!",
    "Gilliam": "What... is the air-speed velocity of an unladen swallow?",
    "Chapman": "We are no longer the knights who say Ni! We are now the\
    knights who say ekki-ekki-ekki-pitang-zoom-boing!"
}

# (1) Inspect Variables with program paused.
print('\nMonty Python Cast')
print('-----------------')
for CastMember in MPCastPhrases.keys():
    print(CastMember + ' ', end="")

# (2) Step through code a line at a time
print('\n\nFamous Lines')
print('------------')
for Line in MPCastPhrases.values():
    print(Line + "\n")

# (3) Modify a command
# Fun with strings
# Cleese's Speech Backwards!
Line = MPCastPhrases['Cleese']
Line = Line[-1:0:-1]
print(Line + "\n")

# (4) Modify a variable in memory.

# (5) Trigger a breakpoint.
# Oops, Palin and Idle sayings accidentally swapped
# Let's fix that with the standard swap algorithm
print(MPCastPhrases["Idle"] + "\n")
Temp = MPCastPhrases["Palin"]
MPCastPhrases["Palin"] = MPCastPhrases["Idle"]
MPCastPhrases["Idle"] = Temp
print(MPCastPhrases["Idle"] + "\n")
# Out:
# Monty Python Cast
# -----------------
# Cleese Palin Jones Idle Gilliam Chapman
#
# Famous Lines
# ------------
# It's not pining, it's passed on! This parrot is no more!    It has ceased to be! It's expired and gone to meet its maker! This    is a late parrot! It's a stiff! Bereft of life, it rests in peace!    If you hadn't nailed it to the perch, it would be pushing up the    daisies! It's rung down the curtain and joined the choir invisible.    This is an ex-parrot!
#
# Bally Jerry pranged his kite right in the how's-your-father;    hairy blighter, dicky-birded, feathered back on his sammy, took a waspy,    flipped over on his Betty Harpers and caught his can in the Bertie.
#
# Spam! Spam! Spam! Spam! Spam! Spam!
#
# Nobody expects the Spanish Inquisition!
#
# What... is the air-speed velocity of an unladen swallow?
#
# We are no longer the knights who say Ni! We are now the    knights who say ekki-ekki-ekki-pitang-zoom-boing!
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Note:</b> The commented numbers in the code---like #(1) Refer to the place in the code that you will be working with during that question.

# %% [markdown]
# 1. Set a breakpoint on the **print** statement below comment #(1). Run your code **using the debug button** or Ctrl-F5.  **Confirm it stops** at your breakpoint. Go to the **Variable explorer** and look at the current value of **CastMember**. Double-click on the dictionary (`MPCastPhrases`) to see the **elements of the dictionary**. **Take a screenshot with the variable explorer showing** and insert it here. Now let it run again by clicking the blue **Continue Executing** button (two triangles pointing right).  **Remove your breakpoint**.

# %% [markdown]
# ![breakcastmember.PNG](attachment:breakcastmember.PNG)

# %% [markdown]
# 2. Place a **breakpoint** on the print statement just before comment #(2). Run the program, which should stop at the new breakpoint. Look at **variable explorer** again, and begin stepping through your code by clicking **Step** or using Ctrl-F10. As you step through the code **one line at a time**, note that you can see the changes in your variables as the program progresses. Insert a **screenshot** of Spyder showing the single-step mode. Note that it **stops again** at the breakpoint, but now the CastMember variable has changed values. **Take a screenshot with the variable explorer showing** and insert it here. Click on **Continue Executing** to **complete the program** and then **remove your breakpoint**.

# %% [markdown]
# ![breakdebugstep.PNG](attachment:breakdebugstep.PNG)

# %% [markdown]
# ![breakdebugvarexplorer.PNG](attachment:breakdebugvarexplorer.PNG)

# %% [markdown]
# 3.  **Break at the line** that reverses the string (`Line = Line[...]`). In the debugger, when it stops at a line, it stops just before the line executes. Edit that line to **replace** `[-1:0:-1]` with `[0:2:]`. **step that line**.  Note that there is **no change due to this edit**. That's because the debugger won't load a new version until the next time it starts. Put a **screenshot** here showing the modified code. **Run the program again** and you will see that the changes show up, **because we restarted** the debugger.

# %% [markdown]
# ![breakdebugmodified.PNG](attachment:breakdebugmodified.PNG)

# %% [markdown]
# 4. While you can't alter code while it's running in the debugger, you can __alter variables in memory__. Set a breakpoint just below the one in 3, with `print(Line)`. Now, go to the __Variable Explorer__ and double click on the entry for the variable `Line` to __open it for editing__. Modify the value of `Line` to be "__My hovercraft is full of eels.__" Step through the print line to __confirm that the change is there.__ Put a **screenshot** here showing the new value for `Line`.

# %% [markdown]
# ![breakdebugmemedit.PNG](attachment:breakdebugmemedit.PNG)

# %% [markdown]
# 5. Create a **conditional breakpoint** on the first `print` statement after comment #(5). The condition should be `"eels" in Line`. Note that this **breakpoint will only work if you made the change** in section 4 above. When it does break, **Double-click on the `MPCastPhrases`** in the Variable Explorer to **bring up the container explorer** showing the contents of the dictionary. Leave the dictionary explorer open as you step through the remaining code, now double click to open another explorer for `MPCastPhrases`.  Note that the second one shows the changes (Palin and Idle values have swapped), while the first does not. Get a screenshot of both dictionary explorers and put it here.

# %% [markdown]
# ![debugcontainerexplorer.PNG](attachment:debugcontainerexplorer.PNG)
